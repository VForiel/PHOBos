# %%
import kbench

dm = kbench.DM()
# Out:
# DEBUG - SDK Install Path: /opt/Boston Micromachines
# DEBUG - BMC_PCIeOpenDM 27BW007#051 0
# DEBUG - 1 BMC PCIe cards installed.
# DEBUG - Using automatic devId: 1
# DEBUG - BMC_PCIeOpenDM opening 0
# INFO - PCIe HW Rev: 20000502
# DEBUG - Loading map file: /opt/Boston Micromachines/Map/KILO507.map expected count: 1024
# INFO - Loading calibration for DM: 27BW07#051_5_3_setof14
# DEBUG - Loading map file: /opt/Boston Micromachines/Map/KILO507.map expected count: 1024
# Loading config file: ./DM_config.json.
# Configuration loaded

# %%
import numpy as np
data = np.ones(169*3)/2

# %%
dm.bmcdm.send_data(data)
# Out:
# 0

# %%
# %%timeit
dm.bmcdm.send_data(data)
# Out:
# 72.5 μs ± 1.97 μs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
# %%timeit
dm.bmcdm.set_segment(0, 0, 0, 0, True, True)
# Out:
# 31.2 μs ± 239 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
# %%timeit
dm[0].set_ptt(0,0,0)
# Out:
# 31.4 μs ± 339 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
# %%timeit
[dm.bmcdm.set_segment(i, 0, 0, 0, True, True) for i in range(4)]
# Out:
# 129 μs ± 9.61 μs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
# %%timeit
[dm[i].set_ptt(0, 0, 0) for i in range(4)]
# Out:
# 124 μs ± 564 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
# %%timeit
[dm[i] for i in range(4)]
# Out:
# 555 ns ± 4.22 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %%
# %%timeit
data[:4*3] = [0 for _ in range(4*3)]
dm.bmcdm.send_data(data)
# Out:
# 73.7 μs ± 781 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)
